# %% [markdown]
# # Star Dataset - EDA
# ![img.jpg](attachment:28156677-ec5d-426a-bb3f-fbce17ef824c.jpg)
#
# ### About Dataset
# Dataset Info:
# This is a dataset consisting of several features of stars.
#
# Some of them are:
#
# - Absolute Temperature (in K)
# - Relative Luminosity (L/Lo)
# - Relative Radius (R/Ro)
# - Absolute Magnitude (Mv)
# - Star Color: (white,Red,Blue,Yellow,yellow-orange etc)
# - Spectral Class: (O,B,A,F,G,K,M)
# - Star Type: **(Red Dwarf, Brown Dwarf, White Dwarf, Main Sequence , SuperGiants, HyperGiants)**
# - Lo = $3.828 \times 10^26$ Watts (Avg Luminosity of Sun)
# - Ro = $6.9551 \times 10^8$ m (Avg Radius of Sun)
#
# Purpose:
# The purpose of making the dataset is to prove that the stars follows a certain graph in the celestial Space ,
# specifically called Hertzsprung-Russell Diagram or simply HR-Diagram,so that we can classify stars by plotting its features based on that graph.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load dataset
df = pd.read_csv("6 class csv.csv")

# %% [markdown]
# ### First Look on Data

# %%
df.head(5)
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %%
df.describe()
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr= df.corr(numeric_only=True)

# %%
sns.heatmap(corr,annot=True);

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['Temperature_(K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute_magnitude(Mv)', 'Star_type', 'Star_color', 'Spectral_Class'],
#       dtype='object')

# %% [markdown]
# #### Observations
# 1. No missing and duplicate values
# 2. some feature have moderate correlation
# 3. 4 numerical and 3 categorical variable

# %% [markdown]
# ### Univariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature_(K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute_magnitude(Mv)  240 non-null    float64
#  4   Star_type               240 non-null    int64
#  5   Star_color              240 non-null    object
#  6   Spectral_Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %%
df['Star_type'].value_counts().plot(kind='bar')
plt.xlabel("Type of Star")
plt.ylabel("Count");

# %%
df['Star_color'].value_counts().plot(kind='bar')
plt.xlabel("Color of Star")
plt.ylabel("Count");

# %%
df['Spectral_Class'].value_counts().plot(kind='bar')
plt.xlabel("Spectral Class")
plt.ylabel("Count");

# %% [markdown]
# ### Bivariate Analysis

# %%
# Temprature and Type of Star
sns.boxplot(data=df,y='Temperature_(K)',x='Star_type');

# %%
sns.boxplot(x="Star_type", y="Luminosity(L/Lo)",data=df);

# %%
sns.boxplot(x=df["Star_type"], y=df["Radius(R/Ro)"]);

# %%
sns.boxplot(x=df["Star_type"], y=df["Absolute_magnitude(Mv)"]);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature_(K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute_magnitude(Mv)  240 non-null    float64
#  4   Star_type               240 non-null    int64
#  5   Star_color              240 non-null    object
#  6   Spectral_Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
# #### Temprature distribution of star types

# %% [markdown]
# Little bit information about stars.\
# 0.Brown Dwarf \
# 1.Red Dwarf \
# 2.White Dwarf \
# 3.Main Sequence \
# 4.Supergiant \
# 5.Hypergiant

# %%
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 0],label='Brown Dwarf')
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 1],label='Red Dwarf')
plt.legend();

# %%
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 2],label='White Dwarf')
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 3],label='Main Sequence')
plt.legend();

# %%
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 4],label='Supergiant')
sns.kdeplot(x='Temperature_(K)',data = df[df['Star_type'] == 5],label='Hyperrgiant')
plt.legend();

# %%
sns.pairplot(df);
